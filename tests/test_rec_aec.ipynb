# %%
from src.core import *
from loguru import logger

from pettingzoo.utils import parallel_to_aec, wrappers
from mpe2 import simple_tag_v3
# Out:
# Running cells with '.venv (Python 3.11.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Projects/moonstone/pzu/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
env = simple_tag_v3.env(render_mode="rgb_array", max_cycles=25)

# %%
env = RecordVideo(env, 
                  "exports/rec_aec_test",
                #   step_trigger=lambda x: x % 100 == 0
                )

for ep in range(5):
        env.reset(seed=42 + ep)
        for agent in env.agent_iter():
                obs, reward, terminated, truncated, info = env.last()
                action = None if (terminated or truncated) else env.action_space(agent).sample()
                env.step(action)

env.close()

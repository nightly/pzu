# %%
from pzu.utils.benchmark import benchmark_env

# %% [markdown]
# ## AEC

# %%
from mpe2 import simple_tag_v3
env = simple_tag_v3.env(render_mode="rgb_array", max_cycles=25)

benchmark_env(env)
# Out:
# Starting performance benchmark 0
# Starting performance benchmark 1
# Starting performance benchmark 2
# Average over 3 runs:
#   turns per time:  9953.308989334413
#   cycles per time: 2488.3272473336033
# (9953.308989334413, 2488.3272473336033)

# %% [markdown]
# ## Parallel

# %%
from pettingzoo.mpe import simple_push_v3
env = simple_push_v3.parallel_env(render_mode="rgb_array")

benchmark_env(env)
# Out:
# Starting performance benchmark 0
# Starting performance benchmark 1
# Starting performance benchmark 2
# Average over 3 runs:
#   turns per time:  15737.115539141145
#   cycles per time: 7868.557769570572
# (15737.115539141145, 7868.557769570572)
